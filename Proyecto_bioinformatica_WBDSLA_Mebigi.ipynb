# %%
# OBJETIVO: Predicción de Lipoproteínas presentes en genoma de Mycobacterium tuberculosis a partir de la secuencia genomica
# de cepa H37RV utilizando a API SignalP6 y posteriormente comparar con lipoproteinas ya identintificadas bajo el mismo
# criterio en bases de datos Mycobrowser una base de referencia para micobacterias

# %%
# !pip3 install pandas
# !pip3 install pyrodigal
# !pip3 install requests
# !pip3 install biopython
# Out:
# Requirement already satisfied: pandas in /home/mebigi/anaconda3/lib/python3.9/site-packages (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: pyrodigal in /home/mebigi/anaconda3/lib/python3.9/site-packages (2.1.0)
# Requirement already satisfied: requests in /home/mebigi/anaconda3/lib/python3.9/site-packages (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from requests) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from requests) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from requests) (2022.9.14)
# Requirement already satisfied: biopython in /home/mebigi/anaconda3/lib/python3.9/site-packages (1.81)
# Requirement already satisfied: numpy in /home/mebigi/anaconda3/lib/python3.9/site-packages (from biopython) (1.21.5)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pyrodigal
import requests
import subprocess
from Bio import SeqIO
from io                 import StringIO
from requests.adapters  import HTTPAdapter, Retry
from typing import TextIO, Union
from pathlib import Path
from time import sleep
from Bio import Entrez
import credenciales

# %%
#1. Obtención de una secuencia genómica

# %%
#lGenoma de Mycobacterium tuberculosis a analizar:
genoma= "NC_000962.3"

# %%
#1.1 Vamos a descargar un genoma usando la biblioteca de NCBI - Entrez

def fetch_sequences(acc: str) -> TextIO:
    try:
        handle = Entrez.efetch(db="nucleotide", id=acc, rettype="fasta")
        return handle
    except requests.HTTPError as err:
        print(err.response.status_code)
        print(err.response.text)
        sleep(60)





def get_fasta_sequences(acc_id: str) -> None:
    def save_fasta(x: str) -> None:
        handle = fetch_sequences(x)
        output_prefix = str(Path.cwd() / x)
        fasta_file = f"{output_prefix}.fasta"

        with open(fasta_file, "w") as f:
            f.write(handle.read())

    if isinstance(acc_id, list):
        [save_fasta(i) for i in acc_id]
    else:
        save_fasta(acc_id)

# %%
genoma_tuberculosis = get_fasta_sequences(genoma)

# %%
#2. Predicción de genes usando pyrodigal

# %%
gff3_header = [
    "seqid",
    "source",
    "type",
    "start",
    "end",
    "score",
    "strand",
    "phase",
    "attributes",
]

# %%
tb_prefix = str(Path.cwd() / genoma)
input_file = SeqIO.read(f"{tb_prefix}.fasta", "fasta")
orf_finder = pyrodigal.OrfFinder()
orf_finder.train(bytes(input_file.seq))

with open(f"{tb_prefix}.gff", "w") as dst:
    fasta_parser = SeqIO.parse(f"{tb_prefix}.fasta", "fasta")
    for i, record in enumerate(fasta_parser):
        genes = orf_finder.find_genes(bytes(record.seq))
        genes.write_gff(dst, sequence_id=record.id, header=(i == 0))
        globals()["genes"] = pd.read_table(f"{tb_prefix}.gff", names=gff3_header, comment="#")

# %%
genes.head()
# Out:
#          seqid            source type  start   end  score strand  phase  \
# 0  NC_000962.3  pyrodigal_v2.1.0  CDS      1  1524  160.1      +      0
# 1  NC_000962.3  pyrodigal_v2.1.0  CDS   2052  3260   83.9      +      0
# 2  NC_000962.3  pyrodigal_v2.1.0  CDS   3280  4437   45.6      +      0
# 3  NC_000962.3  pyrodigal_v2.1.0  CDS   4482  4997   13.8      +      0
# 4  NC_000962.3  pyrodigal_v2.1.0  CDS   5123  7267  312.9      +      0
#
#                                           attributes
# 0  ID=NC_000962.3_1;partial=10;start_type=Edge;rb...
# 1  ID=NC_000962.3_2;partial=00;start_type=ATG;rbs...
# 2  ID=NC_000962.3_3;partial=00;start_type=GTG;rbs...
# 3  ID=NC_000962.3_4;partial=00;start_type=ATG;rbs...
# 4  ID=NC_000962.3_5;partial=00;start_type=ATG;rbs...

# %%
#3. Obtecion de las proteínas a partir de las secuancias nucleotídicas de los genes
aa_file = genoma + ".faa"
tb_prefix = str(Path.cwd() / genoma)

with open(f"{tb_prefix}.gff", "w") as dst:
    fasta_parser = SeqIO.parse(f"{tb_prefix}.fasta", "fasta")
    for i, record in enumerate(fasta_parser):
        genes = orf_finder.find_genes(bytes(record.seq))
        aa_file = genoma + ".faa"
        prefix  = genoma
        with open(aa_file, "w") as orf_gene:
            genes.write_translations(orf_gene,sequence_id=prefix)

# %%
#4. librerias para conexión con servidor SignalP_6
# !pip3 install -U pybiolib
import biolib
signalp_6 = biolib.load('DTU/SignalP_6')
biolib.login()
# token b4jwHu3lRao15Nafh6u5tGVzIG3l3u79j6ULZU2HEhs
biolib.BIOLIB_TOKEN = 'UM6ImC8v6xsMyg41faxfTAuTFfXjymKyam0aPF4KTIg'
# Out:
# Requirement already satisfied: pybiolib in /home/mebigi/anaconda3/lib/python3.9/site-packages (1.1.801)
# Requirement already satisfied: gunicorn>=20.1.0 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from pybiolib) (20.1.0)
# Requirement already satisfied: rich<13.0.0,>=12.4.4 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from pybiolib) (12.6.0)
# Requirement already satisfied: docker>=5.0.3 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from pybiolib) (6.0.1)
# Requirement already satisfied: flask>=2.0.1 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from pybiolib) (2.2.3)
# Requirement already satisfied: click<8.1.0,>=8.0.0 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from pybiolib) (8.0.4)
# Requirement already satisfied: pycryptodome>=3.9.9 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from pybiolib) (3.17)
# Requirement already satisfied: flask-cors>=3.0.10 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from pybiolib) (3.0.10)
# Requirement already satisfied: pyjwt>=2.3.0 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from pybiolib) (2.4.0)
# Requirement already satisfied: importlib-metadata>=1.6.1 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from pybiolib) (4.11.3)
# Requirement already satisfied: appdirs>=1.4.3 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from pybiolib) (1.4.4)
# Requirement already satisfied: requests>=2.25.1 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from pybiolib) (2.28.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from pybiolib) (6.0)
# Requirement already satisfied: packaging>=14.0 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from docker>=5.0.3->pybiolib) (21.3)
# Requirement already satisfied: urllib3>=1.26.0 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from docker>=5.0.3->pybiolib) (1.26.11)
# Requirement already satisfied: websocket-client>=0.32.0 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from docker>=5.0.3->pybiolib) (0.58.0)
# Requirement already satisfied: itsdangerous>=2.0 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from flask>=2.0.1->pybiolib) (2.0.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from flask>=2.0.1->pybiolib) (2.2.3)
# Requirement already satisfied: Jinja2>=3.0 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from flask>=2.0.1->pybiolib) (3.1.2)
# Requirement already satisfied: Six in /home/mebigi/anaconda3/lib/python3.9/site-packages (from flask-cors>=3.0.10->pybiolib) (1.16.0)
# Requirement already satisfied: setuptools>=3.0 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from gunicorn>=20.1.0->pybiolib) (63.4.1)
# Requirement already satisfied: zipp>=0.5 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=1.6.1->pybiolib) (3.8.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from requests>=2.25.1->pybiolib) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from requests>=2.25.1->pybiolib) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from requests>=2.25.1->pybiolib) (2022.9.14)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from rich<13.0.0,>=12.4.4->pybiolib) (2.11.2)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from rich<13.0.0,>=12.4.4->pybiolib) (0.9.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from Jinja2>=3.0->flask>=2.0.1->pybiolib) (2.1.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/mebigi/anaconda3/lib/python3.9/site-packages (from packaging>=14.0->docker>=5.0.3->pybiolib) (3.0.9)
# 2023-03-14 11:26:30,187 | INFO : Loaded project DTU/SignalP-6:0.0.56
# 2023-03-14 11:26:30,188 | INFO : Already signed in

# %%
#permisos para que descargue los resultados
# %%bash
. ~/.bashrc
chmod -R 775 /home/mebigi/WBDSLA_Camp

# %%
#Verificamos la conexion
print(signalp_6.cli(args='--help'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4103/450465069.py in <module>
# ----> 1 print(signalp_6.cli(args='--help'))
#
# NameError: name 'signalp_6' is not defined

# %%
#6. Preparacion de los Archivos
# lo siguewnte vamos a dividir al archivo faa de referencia en archivos con menos de 500 genes gen para 
#luego enviar al signalp6 para hacer la predicion de las seceuncias señales, a fin de evitar que sature el servidor
#Comandos usados en terminal bash
# $csplit -f tb NC_000962.3.faa '/^>/' '{*}'
# luego armado de aprox 400 genes por archivo

#!/bin/bash 
# s=1
# x=482
# t=4082
# f=1
# while [ $x -le $t ]
# do
# while [ $s -le $x ]
# do cat tb$s >> fa_"$f".txt
# s=$(( $s + 1 ))
# done
# x=$(( $x + 400 ))
# f=$(( $f + 1 ))
# done

#luego los reagrupamos en sub grupos de 400 secuancias ya que el envio de mas secuancias al signalp6 está limitados

# %%
#luego a cada archivo los vamos a ir enviando al servidor signalP-6. Se guadaran los resultados de las mas de 4000 genes en distintas subcarpetas
#results_files/ numeradas 1 al 10

for n in range(1,10,1):
    job = signalp_6.cli(args='--fastafile /home/mebigi/WBDSLA_Camp/imput_signalp6/fa_'+str(n)+' --output_dir output --organism other --format txt --mode fast')
    
    if job.get_status() == 'completed':
        job.save_files('results_files/'+str(n)) 
        continue
# Out:
# 2023-03-13 10:09:13,671 | INFO : Job "46122c72-ff75-431b-857c-99034736c7ef" is starting...
# 2023-03-13 10:09:23,079 | INFO : Cloud: Initializing
# 2023-03-13 10:09:23,080 | INFO : Cloud: Downloading Source Files...
# 2023-03-13 10:09:23,081 | INFO : Cloud: Pulling images...
# 2023-03-13 10:09:23,081 | INFO : Cloud: Computing...
# Predicting: 100% 400/400 [23:18<00:00,  3.50s/sequences]
# Writing files: 100% 400/400 [00:00<00:00, 407.04it/s]
# 2023-03-13 10:32:49,086 | INFO : Cloud: Computation finished
# 2023-03-13 10:32:49,087 | INFO : Cloud: Result Ready
# 2023-03-13 10:33:08,894 | INFO : Saving 406 files to results_files/6...
# 2023-03-13 10:33:13,149 | INFO :   - results_files/6/output.gff3
# 2023-03-13 10:34:21,722 | INFO :   - results_files/6/output.json
# 2023-03-13 10:34:24,038 | INFO :   - results_files/6/output_NC_000962_3_2083___2233723___2233980___1___ID_4_2083_partial_00_start_type_ATG_rbs_motif_AGGA_GGAG_GAGG_rbs_spacer_11_12bp_gc_cont_0_663_plot.txt
# 2023-03-13 10:34:25,028 | INFO :   - results_files/6/output_NC_000962_3_2084___2233881___2234216____1___ID_4_2084_partial_00_start_type_GTG_rbs_motif_GGAGG_rbs_spacer_5_10bp_gc_cont_0_673_plot.txt
# 2023-03-13 10:34:30,765 | INFO :   - results_files/6/output_NC_000962_3_2085___2234305___2234649____1___ID_4_2085_partial_00_start_type_GTG_rbs_motif_GGA_GAG_AGG_rbs_spacer_5_10bp_gc_cont_0
# 2023-03-13 11:51:58,854 | INFO :   - results_files/8/output_NC_000962_3_3276___3524129___3525793___1___ID_4_3276_partial_00_start_type_GTG_rbs_motif_GGxGG_rbs_spacer_5_10bp_gc_cont_0_643_plot.txt
# 2023-03-13 11:51:59,941 | INFO :   - results_files/8/output_NC_000962_3_3277___3525790___3527385___1___ID_4_3277_partial_00_start_type_ATG_rbs_motif_AGGA_rbs_spacer_5_10bp_gc_cont_0_655_plot.txt
# 2023-03-13 11:52:01,044 | INFO :   - results_files/8/output_NC_000962_3_3278___3527391___3529307____1___ID_4_3278_partial_00_start_type_GTG_rbs_motif_GGAG_GAGG_rbs_spacer_5_10bp_gc_cont_0_611_plot.txt
# 2023-03-13 11:52:02,162 | INFO :   - results_files/8/output_NC_000962_3_3279___3529338___3529979____1___ID_4_3279_partial_00_start_type_ATG_rbs_motif_None_rbs_spacer_None_gc_cont_0_659_plot.txt
# 2023-03-13 11:52:03,199 | INFO :   - results_files/8/output_NC_000962_3_3280___3529990___3531147____1___ID_4_3280_partial_00_start_type_ATG_rbs_motif_None_rbs_spacer_None_gc_cont_0_623_plot.txt
# 2023-03-13 11:52:04,297 | INFO :   - results_files/8/output_NC_000962_3_3281___3531208___3531645____1___ID_4_3281_partial_00_start_type_ATG_rbs_motif_GGAG_GAGG_rbs_spacer_5_10bp_gc_cont_0_664_plot.txt
# 2023-03-13 11:52:05,342 | INFO :   - results_files/8/output_NC_000962_3_3282___3531642___3532913____1___ID_4_3282_partial_00_start_type_GTG_rbs_motif_None_rbs_spacer_None_gc_cont_0_658_plot.txt
# 2023-03-13 11:52:07,440 | INFO :   - results_files/8/prediction_results.txt
# 2023-03-13 11:52:08,435 | INFO :   - results_files/8/processed_entries.fasta
# 2023-03-13 11:52:09,463 | INFO :   - results_files/8/region_output.gff3
# 2023-03-13 11:52:11,385 | INFO :   - results_files/8/output.md

# %%
# Finalmente se unieron los 10 archivos de salida "prediction_results" en uno solo 
# #!/bin/bash 
#  x=1
#  while [ $x -le 10 ]
#  do
#  tail -n +3 $x/prediction_results.txt >> prediction_results_todos.txt
#  x=$(( $x + 1 ))
# done

# %%
#7. Lectura del archivo con todas los predicciones de secuencias señales para Lipoproteínas
result_signalp6_df = pd.read_csv("/home/mebigi/WBDSLA_Camp/results_files/prediction_results_todos.txt",sep="\t", header=None)

# %%
#result_ignalp6_df[result_ignalp6_df["SP(Sec/SPI)" != 0]]
result_signalp6_df
# Out:
#                                                       0      1         2  \
# 0     NC_000962.3_3683 # 3972552 # 3973592 # -1 # ID...  OTHER  1.000061
# 1     NC_000962.3_3684 # 3973589 # 3974500 # -1 # ID...  OTHER  1.000057
# 2     NC_000962.3_3685 # 3974511 # 3975296 # -1 # ID...  OTHER  1.000055
# 3     NC_000962.3_3686 # 3975369 # 3977060 # 1 # ID=...  OTHER  0.999897
# 4     NC_000962.3_3687 # 3977062 # 3977922 # 1 # ID=...  OTHER  1.000042
# ...                                                 ...    ...       ...
# 4077  NC_000962.3_3678 # 3965884 # 3967038 # -1 # ID...  OTHER  1.000015
# 4078  NC_000962.3_3679 # 3967038 # 3967820 # -1 # ID...  OTHER  1.000057
# 4079  NC_000962.3_3680 # 3967817 # 3968944 # -1 # ID...  OTHER  1.000049
# 4080  NC_000962.3_3681 # 3969343 # 3970563 # 1 # ID=...  OTHER  1.000033
# 4081  NC_000962.3_3682 # 3970705 # 3972453 # -1 # ID...  OTHER  1.000063
#
#              3         4    5    6    7    8
# 0     0.000000  0.000000  0.0  0.0  0.0  NaN
# 1     0.000000  0.000000  0.0  0.0  0.0  NaN
# 2     0.000002  0.000000  0.0  0.0  0.0  NaN
# 3     0.000083  0.000049  0.0  0.0  0.0  NaN
# 4     0.000005  0.000000  0.0  0.0  0.0  NaN
# ...        ...       ...  ...  ...  ...  ...
# 4077  0.000053  0.000001  0.0  0.0  0.0  NaN
# 4078  0.000000  0.000000  0.0  0.0  0.0  NaN
# 4079  0.000000  0.000000  0.0  0.0  0.0  NaN
# 4080  0.000009  0.000000  0.0  0.0  0.0  NaN
# 4081  0.000001  0.000000  0.0  0.0  0.0  NaN
#
# [4082 rows x 9 columns]

# %%
#info para ver los registros si hay nulos
result_signalp6_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4082 entries, 0 to 4081
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       4082 non-null   object
#  1   1       4082 non-null   object
#  2   2       4082 non-null   float64
#  3   3       4082 non-null   float64
#  4   4       4082 non-null   float64
#  5   5       4082 non-null   float64
#  6   6       4082 non-null   float64
#  7   7       4082 non-null   float64
#  8   8       226 non-null    object
# dtypes: float64(6), object(3)
# memory usage: 287.1+ KB

# %%
result_signalp6_df.columns =['ID','Prediction','OTHER','SP(Sec/SPI)','LIPO(Sec/SPII)','TAT(Tat/SPI)','TATLIPO(Tat/SPII)','PILIN(Sec/SPIII)','CS Position']

# %%
result_signalp6_df
# Out:
#                                                      ID Prediction     OTHER  \
# 0     NC_000962.3_3683 # 3972552 # 3973592 # -1 # ID...      OTHER  1.000061
# 1     NC_000962.3_3684 # 3973589 # 3974500 # -1 # ID...      OTHER  1.000057
# 2     NC_000962.3_3685 # 3974511 # 3975296 # -1 # ID...      OTHER  1.000055
# 3     NC_000962.3_3686 # 3975369 # 3977060 # 1 # ID=...      OTHER  0.999897
# 4     NC_000962.3_3687 # 3977062 # 3977922 # 1 # ID=...      OTHER  1.000042
# ...                                                 ...        ...       ...
# 4077  NC_000962.3_3678 # 3965884 # 3967038 # -1 # ID...      OTHER  1.000015
# 4078  NC_000962.3_3679 # 3967038 # 3967820 # -1 # ID...      OTHER  1.000057
# 4079  NC_000962.3_3680 # 3967817 # 3968944 # -1 # ID...      OTHER  1.000049
# 4080  NC_000962.3_3681 # 3969343 # 3970563 # 1 # ID=...      OTHER  1.000033
# 4081  NC_000962.3_3682 # 3970705 # 3972453 # -1 # ID...      OTHER  1.000063
#
#       SP(Sec/SPI)  LIPO(Sec/SPII)  TAT(Tat/SPI)  TATLIPO(Tat/SPII)  \
# 0        0.000000        0.000000           0.0                0.0
# 1        0.000000        0.000000           0.0                0.0
# 2        0.000002        0.000000           0.0                0.0
# 3        0.000083        0.000049           0.0                0.0
# 4        0.000005        0.000000           0.0                0.0
# ...           ...             ...           ...                ...
# 4077     0.000053        0.000001           0.0                0.0
# 4078     0.000000        0.000000           0.0                0.0
# 4079     0.000000        0.000000           0.0                0.0
# 4080     0.000009        0.000000           0.0                0.0
# 4081     0.000001        0.000000           0.0                0.0
#
#       PILIN(Sec/SPIII) CS Position
# 0                  0.0         NaN
# 1                  0.0         NaN
# 2                  0.0         NaN
# 3                  0.0         NaN
# 4                  0.0         NaN
# ...                ...         ...
# 4077               0.0         NaN
# 4078               0.0         NaN
# 4079               0.0         NaN
# 4080               0.0         NaN
# 4081               0.0         NaN
#
# [4082 rows x 9 columns]

# %%
result_signalp6_df = result_signalp6_df.drop(["CS Position"], axis=1)

# %%
result_signalp6_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4082 entries, 0 to 4081
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 4082 non-null   object
#  1   Prediction         4082 non-null   object
#  2   OTHER              4082 non-null   float64
#  3   SP(Sec/SPI)        4082 non-null   float64
#  4   LIPO(Sec/SPII)     4082 non-null   float64
#  5   TAT(Tat/SPI)       4082 non-null   float64
#  6   TATLIPO(Tat/SPII)  4082 non-null   float64
#  7   PILIN(Sec/SPIII)   4082 non-null   float64
# dtypes: float64(6), object(2)
# memory usage: 255.2+ KB

# %%
result_signalp6_df[['seqid','start','end','phase','ID_nro']] = result_signalp6_df["ID"].str.split(" # ", expand = True)

# %%
#8. Filtrado de los datos de interes donde predijo Lipoproteinas Likelihood > 0.4


#result_LIPO = result_signalp6_df[(result_signalp6_df['Prediction'] == 'TATLIPO') | (result_signalp6_df['Prediction'] == 'LIPO')]
result_LIPO = result_LIPO[(result_LIPO['LIPO(Sec/SPII)'] > 0.4) | (result_LIPO['TATLIPO(Tat/SPII)'] > 0.4)]

# %%
result_LIPO
# Out:
#                                                      ID Prediction     OTHER  \
# 54    NC_000962.3_144 # 159700 # 160782 # -1 # ID=4_...    TATLIPO  0.000000
# 101   NC_000962.3_187 # 204065 # 205237 # 1 # ID=4_1...       LIPO  0.001248
# 178   NC_000962.3_256 # 287186 # 288352 # 1 # ID=4_2...       LIPO  0.000000
# 208   NC_000962.3_283 # 316511 # 317503 # -1 # ID=4_...    TATLIPO  0.000000
# 258   NC_000962.3_328 # 377931 # 378587 # 1 # ID=4_3...       LIPO  0.456774
# ...                                                 ...        ...       ...
# 3809  NC_000962.3_3810 # 4105459 # 4107084 # -1 # ID...       LIPO  0.000000
# 3912  NC_000962.3_3913 # 4209047 # 4209526 # 1 # ID=...       LIPO  0.000000
# 3947  NC_000962.3_3948 # 4249878 # 4251005 # 1 # ID=...    TATLIPO  0.000192
# 3961  NC_000962.3_3962 # 4273739 # 4274593 # 1 # ID=...       LIPO  0.041122
# 4063  NC_000962.3_4064 # 4387892 # 4390432 # -1 # ID...       LIPO  0.065153
#
#       SP(Sec/SPI)  LIPO(Sec/SPII)  TAT(Tat/SPI)  TATLIPO(Tat/SPII)  \
# 54       0.000000        0.000006      0.000008           0.999995
# 101      0.008024        0.990632      0.000076           0.000023
# 178      0.000000        1.000020      0.000000           0.000000
# 208      0.000000        0.000216      0.000050           0.999723
# 258      0.049797        0.487810      0.000470           0.000284
# ...           ...             ...           ...                ...
# 3809     0.000046        1.000015      0.000000           0.000000
# 3912     0.000000        1.000043      0.000000           0.000000
# 3947     0.002493        0.006592      0.041162           0.949528
# 3961     0.015608        0.763581      0.024236           0.155091
# 4063     0.040008        0.894332      0.000041           0.000393
#
#       PILIN(Sec/SPIII)             seqid    start      end phase  \
# 54            0.000000   NC_000962.3_144   159700   160782    -1
# 101           0.000009   NC_000962.3_187   204065   205237     1
# 178           0.000000   NC_000962.3_256   287186   288352     1
# 208           0.000000   NC_000962.3_283   316511   317503    -1
# 258           0.004865   NC_000962.3_328   377931   378587     1
# ...                ...               ...      ...      ...   ...
# 3809          0.000000  NC_000962.3_3810  4105459  4107084    -1
# 3912          0.000000  NC_000962.3_3913  4209047  4209526     1
# 3947          0.000022  NC_000962.3_3948  4249878  4251005     1
# 3961          0.000356  NC_000962.3_3962  4273739  4274593     1
# 4063          0.000059  NC_000962.3_4064  4387892  4390432    -1
#
#                                                  ID_nro
# 54    ID=4_144;partial=00;start_type=ATG;rbs_motif=N...
# 101   ID=4_187;partial=00;start_type=ATG;rbs_motif=A...
# 178   ID=4_256;partial=00;start_type=ATG;rbs_motif=N...
# 208   ID=4_283;partial=00;start_type=GTG;rbs_motif=N...
# 258   ID=4_328;partial=00;start_type=ATG;rbs_motif=N...
# ...                                                 ...
# 3809  ID=4_3810;partial=00;start_type=ATG;rbs_motif=...
# 3912  ID=4_3913;partial=00;start_type=GTG;rbs_motif=...
# 3947  ID=4_3948;partial=00;start_type=ATG;rbs_motif=...
# 3961  ID=4_3962;partial=00;start_type=GTG;rbs_motif=...
# 4063  ID=4_4064;partial=00;start_type=ATG;rbs_motif=...
#
# [94 rows x 13 columns]

# %%
len(result_LIPO)
# Out:
# 94

# %%
#/home/mebigi/WBDSLA_Camp/NC_000962.3.faa

lista_candidatos = result_LIPO['seqid'].tolist()
lista_candidatos_sin_espacios= []
for seq_id in lista_candidatos:
    seq_id = seq_id.strip()
    lista_candidatos_sin_espacios.append(seq_id)
lista_candidatos_sin_espacios
# Out:
# ['NC_000962.3_144',
#  'NC_000962.3_187',
#  'NC_000962.3_256',
#  'NC_000962.3_283',
#  'NC_000962.3_328',
#  'NC_000962.3_363',
#  'NC_000962.3_401',
#  'NC_000962.3_420',
#  'NC_000962.3_432',
#  'NC_000962.3_439',
#  'NC_000962.3_440',
#  'NC_000962.3_453',
#  'NC_000962.3_506',
#  'NC_000962.3_553',
#  'NC_000962.3_612',
#  'NC_000962.3_623',
#  'NC_000962.3_635',
#  'NC_000962.3_706',
#  'NC_000962.3_714',
#  'NC_000962.3_875',
#  'NC_000962.3_1006',
#  'NC_000962.3_1044',
#  'NC_000962.3_1054',
#  'NC_000962.3_1060',
#  'NC_000962.3_1066',
#  'NC_000962.3_1113',
#  'NC_000962.3_1223',
#  'NC_000962.3_1238',
#  'NC_000962.3_886',
#  'NC_000962.3_973',
#  'NC_000962.3_977',
#  'NC_000962.3_979',
#  'NC_000962.3_1287',
#  'NC_000962.3_1294',
#  'NC_000962.3_1311',
#  'NC_000962.3_1329',
#  'NC_000962.3_1333',
#  'NC_000962.3_1334',
#  'NC_000962.3_1339',
#  'NC_000962.3_1413',
#  'NC_000962.3_1433',
#  'NC_000962.3_1475',
#  'NC_000962.3_1599',
#  'NC_000962.3_1613',
#  'NC_000962.3_1751',
#  'NC_000962.3_1764',
#  'NC_000962.3_1782',
#  'NC_000962.3_1938',
#  'NC_000962.3_1962',
#  'NC_000962.3_1995',
#  'NC_000962.3_2006',
#  'NC_000962.3_2007',
#  'NC_000962.3_2059',
#  'NC_000962.3_2090',
#  'NC_000962.3_2142',
#  'NC_000962.3_2163',
#  'NC_000962.3_2175',
#  'NC_000962.3_2212',
#  'NC_000962.3_2235',
#  'NC_000962.3_2270',
#  'NC_000962.3_2325',
#  'NC_000962.3_2342',
#  'NC_000962.3_2372',
#  'NC_000962.3_2393',
#  'NC_000962.3_2437',
#  'NC_000962.3_2449',
#  'NC_000962.3_2504',
#  'NC_000962.3_2510',
#  'NC_000962.3_2513',
#  'NC_000962.3_2625',
#  'NC_000962.3_2694',
#  'NC_000962.3_2889',
#  'NC_000962.3_2901',
#  'NC_000962.3_2941',
#  'NC_000962.3_2950',
#  'NC_000962.3_2973',
#  'NC_000962.3_2981',
#  'NC_000962.3_3015',
#  'NC_000962.3_3055',
#  'NC_000962.3_3111',
#  'NC_000962.3_3129',
#  'NC_000962.3_3149',
#  'NC_000962.3_3376',
#  'NC_000962.3_3431',
#  'NC_000962.3_3532',
#  'NC_000962.3_3641',
#  'NC_000962.3_3725',
#  'NC_000962.3_3733',
#  'NC_000962.3_3742',
#  'NC_000962.3_3810',
#  'NC_000962.3_3913',
#  'NC_000962.3_3948',
#  'NC_000962.3_3962',
#  'NC_000962.3_4064']

# %%
#9. a partir de la lista de candidatos obtengo la secuencia de proteinas y posteriormente lo guardo en un archivo

query_str= ""
for record in SeqIO.parse('NC_000962.3.faa', 'fasta'):
    seq_id = record.id
    if (seq_id in lista_candidatos_sin_espacios):
        seq_str = str(record.seq)
        query_str+=">"+seq_id+"\n"+seq_str+"\n"
        query_str = query_str.replace("*","")

# %%
candidatos = open("Lipos_candidatas.txt", "w")
candidatos.write(query_str)
# Out:
# 32324

# %%
candidatos.close()

# %%
# 10. Alineamiento con los genes identificados previamente de referencia, en tuberculosis se le asigna un númer de Rv ademas del nombre del gen

# %%
#Creación de una base de datos tipo BLAST


#bnstallacion Blast local


# wget ncbi-blast-2.13.0+-x64-linux.tar.gz 

# tar ncbi-blast-2.13.0+-x64-linux.tar.gz
# mv ncbi-blast-2.13.0+ blast
# rm ncbi-blast-2.10.0+-x64-linux.tar.gz

# Add a folder for blast databases

# cd blast
# mkdir db
# cd ..

# you become administrator (you enter your password):

# sudo su

# You place the executables in /usr/share to make them usable by everyone:

# mv blast /usr/share
# chmod a+w+r /usr/share/blast/db
# export PATH="$PATH:/usr/share/blast/bin"
# export BLASTDB="/usr/share/blast/db/"
# exit

# %%
from Bio.Blast import NCBIWWW
help(NCBIWWW.qblast)
# Out:
# Help on function qblast in module Bio.Blast.NCBIWWW:
#
# qblast(program, database, sequence, url_base='https://blast.ncbi.nlm.nih.gov/Blast.cgi', auto_format=None, composition_based_statistics=None, db_genetic_code=None, endpoints=None, entrez_query='(none)', expect=10.0, filter=None, gapcosts=None, genetic_code=None, hitlist_size=50, i_thresh=None, layout=None, lcase_mask=None, matrix_name=None, nucl_penalty=None, nucl_reward=None, other_advanced=None, perc_ident=None, phi_pattern=None, query_file=None, query_believe_defline=None, query_from=None, query_to=None, searchsp_eff=None, service=None, threshold=None, ungapped_alignment=None, word_size=None, short_query=None, alignments=500, alignment_view=None, descriptions=500, entrez_links_new_window=None, expect_low=None, expect_high=None, format_entrez_query=None, format_object=None, format_type='XML', ncbi_gi=None, results_file=None, show_overview=None, megablast=None, template_type=None, template_length=None, username='blast', password=None)
#     BLAST search using NCBI's QBLAST server or a cloud service provider.
#
#     Supports all parameters of the old qblast API for Put and Get.
#
#     Please note that NCBI uses the new Common URL API for BLAST searches
#     on the internet (http://ncbi.github.io/blast-cloud/dev/api.html). Thus,
#     some of the parameters used by this function are not (or are no longer)
#     officially supported by NCBI. Although they are still functioning, this
#     may change in the future.
#
#     The Common URL API (http://ncbi.github.io/blast-cloud/dev/api.html) allows
#     doing BLAST searches on cloud servers. To use this feature, please set
#     ``url_base='http://host.my.cloud.service.provider.com/cgi-bin/blast.cgi'``
#     and ``format_object='Alignment'``. For more details, please see
#     https://blast.ncbi.nlm.nih.gov/Blast.cgi?PAGE_TYPE=BlastDocs&DOC_TYPE=CloudBlast
#
#     Some useful parameters:
#
#      - program        blastn, blastp, blastx, tblastn, or tblastx (lower case)
#      - database       Which database to search against (e.g. "nr").
#      - sequence       The sequence to search.
#      - ncbi_gi        TRUE/FALSE whether to give 'gi' identifier.
#      - descriptions   Number of descriptions to show.  Def 500.
#      - alignments     Number of alignments to show.  Def 500.
#      - expect         An expect value cutoff.  Def 10.0.
#      - matrix_name    Specify an alt. matrix (PAM30, PAM70, BLOSUM80, BLOSUM45).
#      - filter         "none" turns off filtering.  Default no filtering
#      - format_type    "HTML", "Text", "ASN.1", or "XML".  Def. "XML".
#      - entrez_query   Entrez query to limit Blast search
#      - hitlist_size   Number of hits to return. Default 50
#      - megablast      TRUE/FALSE whether to use MEga BLAST algorithm (blastn only)
#      - short_query    TRUE/FALSE whether to adjust the search parameters for a
#                       short query sequence. Note that this will override
#                       manually set parameters like word size and e value. Turns
#                       off when sequence length is > 30 residues. Default: None.
#      - service        plain, psi, phi, rpsblast, megablast (lower case)
#
#     This function does no checking of the validity of the parameters
#     and passes the values to the server as is.  More help is available at:
#     https://ncbi.github.io/blast-cloud/dev/api.html

# %%
# Mycobacterium_tuberculosis_H37Rv_proteins_v4.fasta base de datos de referencia 
# descagrado https://mycobrowser.epfl.ch/releases#fasta_proteins4
makeblastdb_path = "/usr/share/blast/bin/makeblastdb"
makeblastdb_command = [makeblastdb_path,'-in',"Mycobacterium_tuberculosis_H37Rv_proteins_v4.fasta",'-dbtype','prot']
subprocess.call(makeblastdb_command)
blastp_path      = "/usr/share/blast/bin/blastp"
blast_out_format = "6 qseqid sseqid qlen slen qstart sstart qend send score evalue length positive"
blast_out_file   = "candidatas.blast.tsv"
blastp_command   = [blastp_path,
                    "-db",          "Mycobacterium_tuberculosis_H37Rv_proteins_v4.fasta",
                    "-query",       "Lipos_candidatas.txt",
                    "-evalue",      "1e-9",
                    "-out",         blast_out_file,
                    "-outfmt",      blast_out_format,
                    "-num_threads", "12"]
subprocess.call(blastp_command)
# Out:
# Building a new DB, current time: 03/17/2023 19:15:04
# New DB name:   /home/mebigi/WBDSLA_Camp/Mycobacterium_tuberculosis_H37Rv_proteins_v4.fasta
# New DB title:  Mycobacterium_tuberculosis_H37Rv_proteins_v4.fasta
# Sequence type: Protein
# Deleted existing Protein BLAST database named /home/mebigi/WBDSLA_Camp/Mycobacterium_tuberculosis_H37Rv_proteins_v4.fasta
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 4031 sequences in 0.058928 seconds.
# FASTA-Reader: Ignoring invalid residues at position(s): On line 18355: 59
# FASTA-Reader: Ignoring invalid residues at position(s): On line 24436: 14
# FASTA-Reader: Ignoring invalid residues at position(s): On line 28172: 7
# Warning: [blastp] Number of threads was reduced to 9 to match the number of available CPUs
# 0

# %%
blastp_column_names = blast_out_format.split(" ")[1:]
blastp_lipo = pd.read_csv("candidatas.blast.tsv",sep="\t",names=blastp_column_names)

# %%
blastp_lipo
# Out:
#                qseqid                        sseqid  qlen  slen  qstart  \
# 0     NC_000962.3_144         Rv0132c|fgd2|Putative   360   360       1
# 1     NC_000962.3_144    Rv0407|fgd1|F420-dependent   360   336      40
# 2     NC_000962.3_144      Rv2951c|Rv2951c|Possible   360   381      92
# 3     NC_000962.3_144      Rv0953c|Rv0953c|Possible   360   282      45
# 4     NC_000962.3_144        Rv2893|Rv2893|Possible   360   325      57
# ..                ...                           ...   ...   ...     ...
# 228  NC_000962.3_3913                Rv3763|lpqH|19   159   159       1
# 229  NC_000962.3_3948       Rv3796|Rv3796|Conserved   375   375       1
# 230  NC_000962.3_3948       Rv2407|Rv2407|Conserved   375   273      63
# 231  NC_000962.3_3962          Rv3810|pirG|Exported   284   284       1
# 232  NC_000962.3_4064  Rv3903c|Rv3903c|Hypothetical   846   846       1
#
#      sstart  qend  send  score         evalue  length  positive
# 0         1   360   360   1883   0.000000e+00     360       360
# 1         2   360   333    501   2.180000e-61     332       176
# 2        74   272   257    181   1.110000e-15     190        89
# 3         4   254   227    170   1.320000e-14     231        99
# 4        27   240   209    172   1.420000e-14     191        86
# ..      ...   ...   ...    ...            ...     ...       ...
# 228       1   159   159    775  1.740000e-108     159       159
# 229       1   375   375   1956   0.000000e+00     375       375
# 230       4   369   263    211   5.600000e-20     314       122
# 231       1   284   284   1367   0.000000e+00     284       284
# 232       1   846   846   4397   0.000000e+00     846       846
#
# [233 rows x 12 columns]

# %%
# me quedo con las secuancias identificadas al 100
blastp_lipo = blastp_lipo[blastp_lipo['qlen'] == blastp_lipo['positive']]
blastp_lipo
# Out:
#                qseqid                        sseqid  qlen  slen  qstart  \
# 0     NC_000962.3_144         Rv0132c|fgd2|Putative   360   360       1
# 7     NC_000962.3_187          Rv0173|lprK|Possible   390   390       1
# 12    NC_000962.3_256          Rv0237|lpqI|Probable   388   388       1
# 13    NC_000962.3_283      Rv0265c|Rv0265c|Probable   330   330       1
# 14    NC_000962.3_328        Rv0309|Rv0309|Possible   218   218       1
# ..                ...                           ...   ...   ...     ...
# 227  NC_000962.3_3810         Rv3666c|dppA|Probable   541   541       1
# 228  NC_000962.3_3913                Rv3763|lpqH|19   159   159       1
# 229  NC_000962.3_3948       Rv3796|Rv3796|Conserved   375   375       1
# 231  NC_000962.3_3962          Rv3810|pirG|Exported   284   284       1
# 232  NC_000962.3_4064  Rv3903c|Rv3903c|Hypothetical   846   846       1
#
#      sstart  qend  send  score         evalue  length  positive
# 0         1   360   360   1883   0.000000e+00     360       360
# 7         1   390   390   2037   0.000000e+00     390       390
# 12        1   388   388   1953   0.000000e+00     388       388
# 13        1   330   330   1696   0.000000e+00     330       330
# 14        1   218   218   1145  6.190000e-163     218       218
# ..      ...   ...   ...    ...            ...     ...       ...
# 227       1   541   541   2838   0.000000e+00     541       541
# 228       1   159   159    775  1.740000e-108     159       159
# 229       1   375   375   1956   0.000000e+00     375       375
# 231       1   284   284   1367   0.000000e+00     284       284
# 232       1   846   846   4397   0.000000e+00     846       846
#
# [90 rows x 12 columns]

# %%
#11 Agrego los datos de prediccion a los resultdos 
#blastp_lipo
#result_LIPO

def macheo_seq(un_resultado):
    df= blastp_lipo
    #print(str(un_resultado['seqid']))
    for index , row in df.iterrows():
     if str(row['qseqid']).strip() == str(un_resultado['seqid']).strip():
        return row['sseqid']

    
    

result_LIPO['RV'] = result_LIPO.apply(macheo_seq, axis="columns")

# %%
#Se identificarion todos los genes predichos por pyrodigal #94 en total

# %%
#Divido los campos sseqid
result_LIPO[["Rv","name", "funtion"]]  = result_LIPO["RV"].str.split("|", expand = True)
result_LIPO
# Out:
#                                                      ID Prediction     OTHER  \
# 54    NC_000962.3_144 # 159700 # 160782 # -1 # ID=4_...    TATLIPO  0.000000
# 101   NC_000962.3_187 # 204065 # 205237 # 1 # ID=4_1...       LIPO  0.001248
# 178   NC_000962.3_256 # 287186 # 288352 # 1 # ID=4_2...       LIPO  0.000000
# 208   NC_000962.3_283 # 316511 # 317503 # -1 # ID=4_...    TATLIPO  0.000000
# 258   NC_000962.3_328 # 377931 # 378587 # 1 # ID=4_3...       LIPO  0.456774
# ...                                                 ...        ...       ...
# 3809  NC_000962.3_3810 # 4105459 # 4107084 # -1 # ID...       LIPO  0.000000
# 3912  NC_000962.3_3913 # 4209047 # 4209526 # 1 # ID=...       LIPO  0.000000
# 3947  NC_000962.3_3948 # 4249878 # 4251005 # 1 # ID=...    TATLIPO  0.000192
# 3961  NC_000962.3_3962 # 4273739 # 4274593 # 1 # ID=...       LIPO  0.041122
# 4063  NC_000962.3_4064 # 4387892 # 4390432 # -1 # ID...       LIPO  0.065153
#
#       SP(Sec/SPI)  LIPO(Sec/SPII)  TAT(Tat/SPI)  TATLIPO(Tat/SPII)  \
# 54       0.000000        0.000006      0.000008           0.999995
# 101      0.008024        0.990632      0.000076           0.000023
# 178      0.000000        1.000020      0.000000           0.000000
# 208      0.000000        0.000216      0.000050           0.999723
# 258      0.049797        0.487810      0.000470           0.000284
# ...           ...             ...           ...                ...
# 3809     0.000046        1.000015      0.000000           0.000000
# 3912     0.000000        1.000043      0.000000           0.000000
# 3947     0.002493        0.006592      0.041162           0.949528
# 3961     0.015608        0.763581      0.024236           0.155091
# 4063     0.040008        0.894332      0.000041           0.000393
#
#       PILIN(Sec/SPIII)             seqid    start      end phase  \
# 54            0.000000   NC_000962.3_144   159700   160782    -1
# 101           0.000009   NC_000962.3_187   204065   205237     1
# 178           0.000000   NC_000962.3_256   287186   288352     1
# 208           0.000000   NC_000962.3_283   316511   317503    -1
# 258           0.004865   NC_000962.3_328   377931   378587     1
# ...                ...               ...      ...      ...   ...
# 3809          0.000000  NC_000962.3_3810  4105459  4107084    -1
# 3912          0.000000  NC_000962.3_3913  4209047  4209526     1
# 3947          0.000022  NC_000962.3_3948  4249878  4251005     1
# 3961          0.000356  NC_000962.3_3962  4273739  4274593     1
# 4063          0.000059  NC_000962.3_4064  4387892  4390432    -1
#
#                                                  ID_nro  \
# 54    ID=4_144;partial=00;start_type=ATG;rbs_motif=N...
# 101   ID=4_187;partial=00;start_type=ATG;rbs_motif=A...
# 178   ID=4_256;partial=00;start_type=ATG;rbs_motif=N...
# 208   ID=4_283;partial=00;start_type=GTG;rbs_motif=N...
# 258   ID=4_328;partial=00;start_type=ATG;rbs_motif=N...
# ...                                                 ...
# 3809  ID=4_3810;partial=00;start_type=ATG;rbs_motif=...
# 3912  ID=4_3913;partial=00;start_type=GTG;rbs_motif=...
# 3947  ID=4_3948;partial=00;start_type=ATG;rbs_motif=...
# 3961  ID=4_3962;partial=00;start_type=GTG;rbs_motif=...
# 4063  ID=4_4064;partial=00;start_type=ATG;rbs_motif=...
#
#                                 RV       Rv     name       funtion  \
# 54           Rv0132c|fgd2|Putative  Rv0132c     fgd2      Putative
# 101           Rv0173|lprK|Possible   Rv0173     lprK      Possible
# 178           Rv0237|lpqI|Probable   Rv0237     lpqI      Probable
# 208       Rv0265c|Rv0265c|Probable  Rv0265c  Rv0265c      Probable
# 258         Rv0309|Rv0309|Possible   Rv0309   Rv0309      Possible
# ...                            ...      ...      ...           ...
# 3809         Rv3666c|dppA|Probable  Rv3666c     dppA      Probable
# 3912                Rv3763|lpqH|19   Rv3763     lpqH            19
# 3947       Rv3796|Rv3796|Conserved   Rv3796   Rv3796     Conserved
# 3961          Rv3810|pirG|Exported   Rv3810     pirG      Exported
# 4063  Rv3903c|Rv3903c|Hypothetical  Rv3903c  Rv3903c  Hypothetical
#
#                                            Descriptions
# 54                                                 None
# 101   Possible Mce-family lipoprotein LprK (Mce-fami...
# 178                 Probable conserved lipoprotein LpqI
# 208     Probable periplasmic iron-transport lipoprotein
# 258                                                None
# ...                                                 ...
# 3809  Probable periplasmic dipeptide-binding lipopro...
# 3912          19 kDa lipoprotein antigen precursor LpqH
# 3947                                               None
# 3961                                               None
# 4063                                               None
#
# [94 rows x 18 columns]

# %%
# ler el listados de lipoproteinas categoriazadas segun busqueda "Lipoprotein" en base de datos Mycrobrowser
# lipoproteinas_tuberculist.txt
tubeculist_lipo = pd.read_csv("lipoproteinas_tuberculist.txt",sep="\t", header=None)
tubeculist_lipo.columns = ['#','RV_ID','name','Descriptions']
tubeculist_lipo
# Out:
#      #     RV_ID      name                                       Descriptions
# 0    1   Rv0237      lpqI                 Probable conserved lipoprotein LpqI
# 1    2  Rv0265c   Rv0265c     Probable periplasmic iron-transport lipoprotein
# 2    3   Rv0173      lprK   Possible Mce-family lipoprotein LprK (Mce-fami...
# 3    4  Rv0179c      lprO                           Possible lipoprotein LprO
# 4    5  Rv0399c      lpqK                 Possible conserved lipoprotein LpqK
# ..  ..       ...       ...                                                ...
# 83  84   Rv3390      lpqD                 Probable conserved lipoprotein LpqD
# 84  85   Rv3576      lppH                 Possible conserved lipoprotein LppH
# 85  86  Rv3666c      dppA   Probable periplasmic dipeptide-binding lipopro...
# 86  87  Rv3759c      proX   Possible osmoprotectant (glycine betaine/carni...
# 87  88   Rv3763      lpqH           19 kDa lipoprotein antigen precursor LpqH
#
# [88 rows x 4 columns]

# %%
def macheo_seq(un_resultado):
    df= tubeculist_lipo
    for index , row in df.iterrows():
        if str(row['RV_ID']).strip() == str(un_resultado['Rv']).strip():
            return row['Descriptions']

    
    
result_LIPO['Descriptions'] = ''
result_LIPO['Descriptions'] = result_LIPO.apply(macheo_seq, axis="columns")

# %%
result_LIPO
# Out:
#                                                      ID Prediction     OTHER  \
# 54    NC_000962.3_144 # 159700 # 160782 # -1 # ID=4_...    TATLIPO  0.000000
# 101   NC_000962.3_187 # 204065 # 205237 # 1 # ID=4_1...       LIPO  0.001248
# 178   NC_000962.3_256 # 287186 # 288352 # 1 # ID=4_2...       LIPO  0.000000
# 208   NC_000962.3_283 # 316511 # 317503 # -1 # ID=4_...    TATLIPO  0.000000
# 258   NC_000962.3_328 # 377931 # 378587 # 1 # ID=4_3...       LIPO  0.456774
# ...                                                 ...        ...       ...
# 3809  NC_000962.3_3810 # 4105459 # 4107084 # -1 # ID...       LIPO  0.000000
# 3912  NC_000962.3_3913 # 4209047 # 4209526 # 1 # ID=...       LIPO  0.000000
# 3947  NC_000962.3_3948 # 4249878 # 4251005 # 1 # ID=...    TATLIPO  0.000192
# 3961  NC_000962.3_3962 # 4273739 # 4274593 # 1 # ID=...       LIPO  0.041122
# 4063  NC_000962.3_4064 # 4387892 # 4390432 # -1 # ID...       LIPO  0.065153
#
#       SP(Sec/SPI)  LIPO(Sec/SPII)  TAT(Tat/SPI)  TATLIPO(Tat/SPII)  \
# 54       0.000000        0.000006      0.000008           0.999995
# 101      0.008024        0.990632      0.000076           0.000023
# 178      0.000000        1.000020      0.000000           0.000000
# 208      0.000000        0.000216      0.000050           0.999723
# 258      0.049797        0.487810      0.000470           0.000284
# ...           ...             ...           ...                ...
# 3809     0.000046        1.000015      0.000000           0.000000
# 3912     0.000000        1.000043      0.000000           0.000000
# 3947     0.002493        0.006592      0.041162           0.949528
# 3961     0.015608        0.763581      0.024236           0.155091
# 4063     0.040008        0.894332      0.000041           0.000393
#
#       PILIN(Sec/SPIII)             seqid    start      end phase  \
# 54            0.000000   NC_000962.3_144   159700   160782    -1
# 101           0.000009   NC_000962.3_187   204065   205237     1
# 178           0.000000   NC_000962.3_256   287186   288352     1
# 208           0.000000   NC_000962.3_283   316511   317503    -1
# 258           0.004865   NC_000962.3_328   377931   378587     1
# ...                ...               ...      ...      ...   ...
# 3809          0.000000  NC_000962.3_3810  4105459  4107084    -1
# 3912          0.000000  NC_000962.3_3913  4209047  4209526     1
# 3947          0.000022  NC_000962.3_3948  4249878  4251005     1
# 3961          0.000356  NC_000962.3_3962  4273739  4274593     1
# 4063          0.000059  NC_000962.3_4064  4387892  4390432    -1
#
#                                                  ID_nro  \
# 54    ID=4_144;partial=00;start_type=ATG;rbs_motif=N...
# 101   ID=4_187;partial=00;start_type=ATG;rbs_motif=A...
# 178   ID=4_256;partial=00;start_type=ATG;rbs_motif=N...
# 208   ID=4_283;partial=00;start_type=GTG;rbs_motif=N...
# 258   ID=4_328;partial=00;start_type=ATG;rbs_motif=N...
# ...                                                 ...
# 3809  ID=4_3810;partial=00;start_type=ATG;rbs_motif=...
# 3912  ID=4_3913;partial=00;start_type=GTG;rbs_motif=...
# 3947  ID=4_3948;partial=00;start_type=ATG;rbs_motif=...
# 3961  ID=4_3962;partial=00;start_type=GTG;rbs_motif=...
# 4063  ID=4_4064;partial=00;start_type=ATG;rbs_motif=...
#
#                                 RV       Rv     name       funtion  \
# 54           Rv0132c|fgd2|Putative  Rv0132c     fgd2      Putative
# 101           Rv0173|lprK|Possible   Rv0173     lprK      Possible
# 178           Rv0237|lpqI|Probable   Rv0237     lpqI      Probable
# 208       Rv0265c|Rv0265c|Probable  Rv0265c  Rv0265c      Probable
# 258         Rv0309|Rv0309|Possible   Rv0309   Rv0309      Possible
# ...                            ...      ...      ...           ...
# 3809         Rv3666c|dppA|Probable  Rv3666c     dppA      Probable
# 3912                Rv3763|lpqH|19   Rv3763     lpqH            19
# 3947       Rv3796|Rv3796|Conserved   Rv3796   Rv3796     Conserved
# 3961          Rv3810|pirG|Exported   Rv3810     pirG      Exported
# 4063  Rv3903c|Rv3903c|Hypothetical  Rv3903c  Rv3903c  Hypothetical
#
#                                            Descriptions
# 54                                                 None
# 101   Possible Mce-family lipoprotein LprK (Mce-fami...
# 178                 Probable conserved lipoprotein LpqI
# 208     Probable periplasmic iron-transport lipoprotein
# 258                                                None
# ...                                                 ...
# 3809  Probable periplasmic dipeptide-binding lipopro...
# 3912          19 kDa lipoprotein antigen precursor LpqH
# 3947                                               None
# 3961                                               None
# 4063                                               None
#
# [94 rows x 18 columns]

# %%
# Encontramos 4 nuevas posiblers lipo proteinas predichas con signalP6
result_LIPO[result_LIPO['Descriptions'].isnull()]
# Out:
#                                                      ID Prediction     OTHER  \
# 54    NC_000962.3_144 # 159700 # 160782 # -1 # ID=4_...    TATLIPO  0.000000
# 258   NC_000962.3_328 # 377931 # 378587 # 1 # ID=4_3...       LIPO  0.456774
# 340   NC_000962.3_401 # 456915 # 457823 # -1 # ID=4_...       LIPO  0.000000
# 552   ID=4_553;partial=00;start_type=ATG;rbs_motif=A...
# 713   ID=4_714;partial=00;start_type=GTG;rbs_motif=N...
# 926   ID=4_1044;partial=00;start_type=GTG;rbs_motif=...
# 936   ID=4_1054;partial=00;start_type=ATG;rbs_motif=...
# 1120  ID=4_1238;partial=00;start_type=GTG;rbs_motif=...
# 1168  ID=4_886;partial=00;start_type=ATG;rbs_motif=A...
# 1412  ID=4_1413;partial=00;start_type=ATG;rbs_motif=...
# 1474  ID=4_1475;partial=00;start_type=ATG;rbs_motif=...
# 1598  ID=4_1599;partial=00;start_type=GTG;rbs_motif=...
# 1781  ID=4_1782;partial=00;start_type=ATG;rbs_motif=...
# 2089  ID=4_2090;partial=00;start_type=ATG;rbs_motif=...
# 2162  ID=4_2163;partial=00;start_type=ATG;rbs_motif=...
# 2174  ID=4_2175;partial=00;start_type=ATG;rbs_motif=...
# 2324  ID=4_2325;partial=00;start_type=ATG;rbs_motif=...
# 2341  ID=4_2342;partial=00;start_type=GTG;rbs_motif=...
# 2392  ID=4_2393;partial=00;start_type=GTG;rbs_motif=...
# 2448  ID=4_2449;partial=00;start_type=ATG;rbs_motif=...
# 2503  ID=4_2504;partial=00;start_type=ATG;rbs_motif=...
# 2624  ID=4_2625;partial=00;start_type=ATG;rbs_motif=...
# 2949  ID=4_2950;partial=00;start_type=GTG;rbs_motif=...
# 3148  ID=4_3149;partial=00;start_type=ATG;rbs_motif=...
# 3640  ID=4_3641;partial=00;start_type=ATG;rbs_motif=...
# 3947  ID=4_3948;partial=00;start_type=ATG;rbs_motif=...
# 3961  ID=4_3962;partial=00;start_type=GTG;rbs_motif=...
# 4063  ID=4_4064;partial=00;start_type=ATG;rbs_motif=...
#
#                                 RV       Rv     name       funtion  \
# 54           Rv0132c|fgd2|Putative  Rv0132c     fgd2      Putative
# 258         Rv0309|Rv0309|Possible   Rv0309   Rv0309      Possible
# 340   Rv0381c|Rv0381c|Hypothetical  Rv0381c  Rv0381c  Hypothetical
# 397        Rv0432|sodC|Periplasmic   Rv0432     sodC   Periplasmic
# 552         Rv0526|Rv0526|Possible   Rv0526   Rv0526      Possible
# 713      Rv0679c|Rv0679c|Conserved  Rv0679c  Rv0679c     Conserved
# 926          Rv0999|Rv0999|Unknown   Rv0999   Rv0999       Unknown
# 936           Rv1009|rpfB|Probable   Rv1009     rpfB      Probable
# 1120          Rv1180|pks3|Probable   Rv1180     pks3      Probable
# 1168      Rv0846c|Rv0846c|Probable  Rv0846c  Rv0846c      Probable
# 1412    Rv1351|Rv1351|Hypothetical   Rv1351   Rv1351  Hypothetical
# 1474                          None     None     None          None
# 1598         Rv1527c|pks5|Probable  Rv1527c     pks5      Probable
# 1781                          None     None     None          None
# 2089         Rv1995|Rv1995|Unknown   Rv1995   Rv1995       Unknown
# 2162            Rv2068c|blaC|Class  Rv2068c     blaC         Class
# 2174                          None     None     None          None
# 2324         Rv2224c|caeA|Probable  Rv2224c     caeA      Probable
# 2341       Rv2240c|Rv2240c|Unknown  Rv2240c  Rv2240c       Unknown
# 2392     Rv2293c|Rv2293c|Conserved  Rv2293c  Rv2293c     Conserved
# 2448                          None     None     None          None
# 2503          Rv2394|ggtB|Probable   Rv2394     ggtB      Probable
# 2624         Rv2518c|ldtB|Probable  Rv2518c     ldtB      Probable
# 2949        Rv2843|Rv2843|Probable   Rv2843   Rv2843      Probable
# 3148         Rv3033|Rv3033|Unknown   Rv3033   Rv3033       Unknown
# 3640         Rv3495c|lprN|Possible  Rv3495c     lprN      Possible
# 3947       Rv3796|Rv3796|Conserved   Rv3796   Rv3796     Conserved
# 3961          Rv3810|pirG|Exported   Rv3810     pirG      Exported
# 4063  Rv3903c|Rv3903c|Hypothetical  Rv3903c  Rv3903c  Hypothetical
#
#      Descriptions
# 54           None
# 258          None
# 340          None
# 397          None
# 552          None
# 713          None
# 926          None
# 936          None
# 1120         None
# 1168         None
# 1412         None
# 1474         None
# 1598         None
# 1781         None
# 2089         None
# 2162         None
# 2174         None
# 2324         None
# 2341         None
# 2392         None
# 2448         None
# 2503         None
# 2624         None
# 2949         None
# 3148         None
# 3640         None
# 3947         None
# 3961         None
# 4063         None

# %%
len(result_LIPO[result_LIPO['Descriptions'].isnull()])
# Out:
# 29

# %%
#12. obtención de la tabla final 


tabla_final = pd.DataFrame()
tabla_final['Rv_id'] = result_LIPO["Rv"]
tabla_final['name'] = result_LIPO["name"]
tabla_final['Descriptions'] = result_LIPO["Descriptions"]
tabla_final['LIPO(Sec/SPII)'] = result_LIPO["LIPO(Sec/SPII)"]
tabla_final['TATLIPO(Tat/SPII)'] = result_LIPO["TATLIPO(Tat/SPII)"]

# %%
tabla_final.to_csv('tabla_final_lipos.txt')
tabla_final
# Out:
#         Rv_id     name                                       Descriptions  \
# 54    Rv0132c     fgd2                                               None
# 101    Rv0173     lprK  Possible Mce-family lipoprotein LprK (Mce-fami...
# 178    Rv0237     lpqI                Probable conserved lipoprotein LpqI
# 208   Rv0265c  Rv0265c    Probable periplasmic iron-transport lipoprotein
# 258    Rv0309   Rv0309                                               None
# ...       ...      ...                                                ...
# 3809  Rv3666c     dppA  Probable periplasmic dipeptide-binding lipopro...
# 3912   Rv3763     lpqH          19 kDa lipoprotein antigen precursor LpqH
# 3947   Rv3796   Rv3796                                               None
# 3961   Rv3810     pirG                                               None
# 4063  Rv3903c  Rv3903c                                               None
#
#       LIPO(Sec/SPII)  TATLIPO(Tat/SPII)
# 54          0.000006           0.999995
# 101         0.990632           0.000023
# 178         1.000020           0.000000
# 208         0.000216           0.999723
# 258         0.487810           0.000284
# ...              ...                ...
# 3809        1.000015           0.000000
# 3912        1.000043           0.000000
# 3947        0.006592           0.949528
# 3961        0.763581           0.155091
# 4063        0.894332           0.000393
#
# [94 rows x 5 columns]

# %%
# Conclusión Se se predijeron 94 lipoproteinas, como resultado preliminar se obtuvieron 29 lipoproteinas que se diferencian de la lista ya anotadas. 
#Estos daos deben ser auditados manualmente a fin de corrregir posibles diferencias en la anotación respecto a la Base de datos de referencia.
